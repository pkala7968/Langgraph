# %%
from typing import TypedDict, List
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os

load_dotenv()   
api_key=os.getenv("GOOGLE_API_KEY")

# %%
class AgentState(TypedDict):
    messages: List[HumanMessage]

llm= ChatGoogleGenerativeAI(api_key=api_key, model="gemini-2.5-flash")

def process(state: AgentState)-> AgentState:
    response= llm.invoke(state["messages"])
    print(f"AI: {response.content}" )

# %%
graph= StateGraph(AgentState)

graph.add_node("process", process)
graph.add_edge(START, "process")
graph.add_edge("process", END)
app= graph.compile()

# %%
from IPython.display import display, Image

display(Image(app.get_graph().draw_mermaid_png()))

# %%
user_input= input("You: ")
app.invoke({"messages": [HumanMessage(content=user_input)]})
# Out:
# AI: Machine Learning (ML) is a subfield of Artificial Intelligence (AI) that focuses on **teaching computers to learn from data without being explicitly programmed for every possible scenario.**
#
# Instead of a programmer writing specific instructions for every task, ML algorithms are fed large amounts of data. These algorithms then analyze the data, identify patterns, make predictions, and adapt their behavior based on what they've "learned."
#
# Think of it like this:
#
# *   **Traditional Programming:** You give the computer **rules** and **data**, and it gives you **answers**. (e.g., "If an email contains 'VIAGRA' and 'LOAN', mark it as spam.")
# *   **Machine Learning:** You give the computer **data** and **answers** (or desired outcomes), and it figures out the **rules** itself. (e.g., You show it millions of emails labeled as "spam" or "not spam," and it learns what characteristics make an email spam.)
#
# **Key Concepts of Machine Learning:**
#
# 1.  **Data:** This is the fuel for ML. The quality and quantity of data directly impact how well a machine learning model performs.
# 2.  **Algorithms:** These are the computational methods or "recipes" that enable the machine to learn from data. Examples include linear regression, decision trees, support vector machines, neural networks, etc.
# 3.  **Model:** The outcome of the learning process. After an algorithm has been trained on data, it produces a "model" which is essentially the learned patterns, rules, or representations that can be used to make predictions or decisions on new, unseen data.
# 4.  **Training:** The process where the algorithm learns from the data to build the model.
# 5.  **Prediction/Inference:** Using the trained model to make a prediction or decision on new data.
#
# **How it Works (Simplified):**
#
# 1.  **Data Collection:** Gather relevant data (e.g., images of cats and dogs, customer purchase history, sensor readings).
# 2.  **Data Preprocessing:** Clean, transform, and prepare the data so the algorithm can understand it.
# 3.  **Choose an Algorithm:** Select the right learning algorithm for the task (e.g., classification, regression, clustering).
# 4.  **Training:** Feed the processed data to the algorithm. The algorithm adjusts its internal parameters to find patterns and relationships. This creates the "model."
# 5.  **Evaluation:** Test the model on new, unseen data to see how well it performs and if it generalizes well.
# 6.  **Deployment:** Once the model is satisfactory, it can be used in real-world applications.
#
# **Types of Machine Learning:**
#
# *   **Supervised Learning:** The algorithm learns from labeled data (input-output pairs).
#     *   **Classification:** Predicts a category (e.g., spam/not spam, cat/dog, disease A/B/C).
#     *   **Regression:** Predicts a continuous value (e.g., house prices, temperature, stock prices).
# *   **Unsupervised Learning:** The algorithm learns from unlabeled data, finding hidden patterns or structures on its own.
#     *   **Clustering:** Groups similar data points together (e.g., customer segmentation, document categorization).
#     *   **Dimensionality Reduction:** Reduces the number of features in the data while retaining important information.
# *   **Reinforcement Learning:** An agent learns by interacting with an environment, receiving rewards for desired actions and penalties for undesirable ones.
#     *   Examples: Game playing (AlphaGo), robotics, self-driving cars.
#
# **Why is it Important?**
#
# Machine learning enables systems to:
# *   **Automate complex tasks:** That are difficult to program manually.
# *   **Make data-driven predictions and decisions:** With high accuracy.
# *   **Discover hidden insights and patterns:** In large datasets.
# *   **Adapt and improve over time:** As more data becomes available.
#
# **Real-World Examples:**
#
# *   **Recommendation Systems:** (Netflix, Amazon, YouTube) suggesting products or content you might like.
# *   **Spam Filters:** Identifying and filtering unwanted emails.
# *   **Facial Recognition:** Unlocking your phone or tagging photos.
# *   **Voice Assistants:** (Siri, Alexa, Google Assistant) understanding and responding to natural language.
# *   **Fraud Detection:** Flagging suspicious financial transactions.
# *   **Medical Diagnosis:** Assisting doctors in identifying diseases from images or patient data.
# *   **Self-Driving Cars:** Perceiving their environment and making navigation decisions.
#
# In essence, Machine Learning is about building intelligent systems that can learn from experience, much like humans do, but on a massive scale and with incredible speed.
# {'messages': [HumanMessage(content='what is machine learning?', additional_kwargs={}, response_metadata={})]}
